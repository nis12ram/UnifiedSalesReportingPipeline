# %%
# %run "./Configs"

# %%
# UnifiedSalesDeltaTable Setup
dbutils.notebook.run(
    "./DeltaTablesSetup/UnifiedSalesDeltaTableSetup", 
    120, 
    {"UNIFIED_SALES_TABLE_PATH": UNIFIED_SALES_TABLE_PATH, 
     "UC_CATALOG_NAME": UC_CATALOG_NAME,
     "UC_SCHEMA_NAME": UC_SCHEMA_NAME}
)

# %%
# ExtendedSalesDeltaTable Setup
dbutils.notebook.run(
    "./DeltaTablesSetup/ExtendedSalesDeltaTableSetup", 
    120, 
    {"EXTENDED_SALES_TABLE_PATH": EXTENDED_SALES_TABLE_PATH,
     "UC_CATALOG_NAME": UC_CATALOG_NAME,
     "UC_SCHEMA_NAME": UC_SCHEMA_NAME}
)

# %%
# QuarantinedSalesDeltaTable Setup
dbutils.notebook.run(
    "./DeltaTablesSetup/QuarantinedSalesDeltaTableSetup", 
    120, 
    {"QUARANTINED_SALES_TABLE_PATH": QUARANTINED_SALES_TABLE_PATH,
     "UC_CATALOG_NAME": UC_CATALOG_NAME,
     "UC_SCHEMA_NAME": UC_SCHEMA_NAME}
)

# %%
dbutils.notebook.exit("All Setup completed")
